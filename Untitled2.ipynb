# %%
# %matplotlib inline
from alyssa import downloader, paths, checker, indicators

# %%
wig = downloader.stooq('WIG','d')

# %%
oecd = indicators.OECD_growing_countries()

# %%
dates = checker.FindExtremes(oecd,'Growing countries', first_rolling=8,second_rolling=4,final_format='lows')

# %%
paths.Paths(wig,dates,'WIG',Range_start=-20,Range_end=40,Plot_date='')
# Out:
# ERROR! 1998-08-22 00:00:00 is not in the df.
# ERROR! 2001-04-22 00:00:00 is not in the df.
# ERROR! 2008-11-22 00:00:00 is not in the df.
# ERROR! 2012-04-22 00:00:00 is not in the df.
